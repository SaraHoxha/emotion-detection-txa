# %%
import pandas as pd

# %%
data = pd.read_csv('train_yangswei_85.csv')

# %%
data.head()
# Out:
#                                                 text    label
# 0  How can i miss work if i work from home questi...      joy
# 1  How do you deal with being the only person in ...  sadness
# 2  I began my application to remote jobs yesterda...      joy
# 3  Anyone else question mine sit in the window si...      joy
# 4  What household chore did you get done today wh...    anger

# %%
label_counts = data['label'].value_counts()
label_counts
# Out:
# label
# joy         53409
# sadness     16033
# anger       13183
# fear         4621
# surprise     1250
# love          656
# Name: count, dtype: int64

# %%
import spacy
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk import download

# %%
# Download necessary NLTK resources
download('punkt')  # For tokenization
download('stopwords')  # For stopwords

# Load SpaCy English model
nlp = spacy.load("en_core_web_sm")
# Out:
# [nltk_data] Downloading package punkt to C:\Users\minhd/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\minhd/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def preprocess_text(text):
    # lowercase 
    text = text.lower()

    tokens = word_tokenize(text)

    # remove stopwords
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word.isalpha() and word not in stop_words]

    # lemmatization (using SpaCy)
    doc = nlp(" ".join(tokens))
    lemmatized_tokens = [token.lemma_ for token in doc]

    # return to string 
    return " ".join(lemmatized_tokens)

# %%
data['processed_text'] = data['text'].apply(preprocess_text)

# %%
data
# Out:
#                                                     text    label  \
# 0      How can i miss work if i work from home questi...      joy
# 1      How do you deal with being the only person in ...  sadness
# 2      I began my application to remote jobs yesterda...      joy
# 3      Anyone else question mine sit in the window si...      joy
# 4      What household chore did you get done today wh...    anger
# ...                                                  ...      ...
# 89147  14 Best Remote Job sites, hope this helps  con...      joy
# 89148  If you speak any of the following languages an...      joy
# 89149  What do you listen to while working remote que...     fear
# 89150  Finally found a WFH position exclamation excla...      joy
# 89151  What is the one item that has made your work f...  sadness
#
#                                           processed_text
# 0      miss work work home question way would office ...
# 1      deal person social circle wfh question family ...
# 2      begin application remote job yesterday consist...
# 3      anyone else question mine sit window sill desk...
# 4      household chore get do today wfh exclamation s...
# ...                                                  ...
# 89147  well remote job site hope help consider op hav...
# 89148  speak follow language english fluently let kno...
# 89149  listen work remote question youtube video back...
# 89150  finally find wfh position exclamation exclamat...
# 89151  one item make work home life well question job...
#
# [89152 rows x 3 columns]

# %%
test_data = pd.read_csv('test_yangswei_85.csv')

# %%
test_data['processed_text'] = test_data['text'].apply(preprocess_text)

# %%
test_data
# Out:
#                                                     text    label  \
# 0      RTO is the new war on the middle class don't f...      joy
# 1      How do you continue with life outside of work ...      joy
# 2      Very desperate for a job would you know a pers...     fear
# 3      What time do you start working most days quest...      joy
# 4      What are good job sites to find LEGIT remote w...      joy
# ...                                                  ...      ...
# 22284  Its been 6 months now, all hope lost in additi...  sadness
# 22285  Do I clock in office hours even though I don’t...      joy
# 22286  Would you consider moving to a small town in O...      joy
# 22287  I tried to be a WFH employee and failed misera...  sadness
# 22288  I am "disabled." I just mask it very well. Man...  sadness
#
#                                           processed_text
# 0      rto new war middle class fire tie package aver...
# 1      continue life outside work mental exhaustion c...
# 2      desperate job would know person come apply job...
# 3      time start work day question set hour like get...
# 4      good job site find legit remote work like dece...
# ...                                                  ...
# 22284  month hope lose addition research company othe...
# 22285  clock office hour even though enough work ques...
# 22286  would consider move small town oregon think ex...
# 22287  try wfh employee fail miserably tip hat every ...
# 22288  disabled mask well many job ask disability see...
#
# [22289 rows x 3 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
from sklearn.metrics import classification_report

X_train = data['processed_text']
y_train = data['label']

X_test = test_data['processed_text']
y_test = test_data['label']

# %%
import time
from sklearn.feature_extraction.text import CountVectorizer  # Import CountVectorizer

start_time = time.time()
# vect = CountVectorizer()  # Convert a collection of text documents to a matrix of token counts.
vect = CountVectorizer(min_df=5)  # Convert a collection of text documents to a matrix of token counts.

print('fit')
vect.fit(X_train)

print('transform') # actual counting
X_train_tok = vect.transform(X_train)

end_time = time.time()
print('done')

# The two steps above can be condensed in a single step that processes train
# data only once.

X_test_tok = vect.transform(X_test)
# Out:
# fit
# transform
# done

# %%
elapsed_time = end_time - start_time
print(f"Time employed: {elapsed_time:.2f} seconds")
len(vect.vocabulary_)
# Out:
# Time employed: 4.25 seconds
# 9344

# %%
vect.vocabulary_
# Out:
# {'miss': 5210,
#  'work': 9207,
#  'home': 3837,
#  'question': 6544,
#  'way': 9035,
#  'would': 9245,
#  'office': 5645,
#  'sick': 7435,
#  'consider': 1675,
#  'go': 3481,
#  'sitting': 7488,
#  'desk': 2174,
#  'day': 2016,
#  'due': 2520,
#  'exhaustion': 2879,
#  'say': 7153,
#  'feel': 3026,
#  'well': 9071,
#  'need': 5424,
#  'elaborate': 2617,
#  'reason': 6658,
#  'deal': 2034,
#  'person': 6028,
#  'social': 7606,
#  'circle': 1364,
#  'wfh': 9089,
#  'family': 2972,
#  'extra': 2929,
#  'time': 8341,
#  'give': 3456,
#  'could': 1796,
#  'see': 7250,
#  'result': 6923,
#  'isolation': 4384,
#  'begin': 750,
#  'application': 404,
#  'remote': 6801,
#  'job': 4444,
#  'yesterday': 9305,
#  'consistently': 1682,
#  'apply': 406,
#  'comment': 1529,
#  'back': 621,
#  'hire': 3808,
#  'long': 4829,
#  'take': 8118,
#  'pm': 6170,
#  'taxis': 8153,
#  'winwin': 9167,
#  'anyone': 371,
#  'else': 2645,
#  'mine': 5177,
#  'sit': 7482,
#  'window': 9159,
#  'lap': 4601,
#  'chair': 1260,
#  'towards': 8417,
#  'front': 3290,
#  'half': 3635,
#  'try': 8525,
#  'walk': 8987,
#  'across': 86,
#  'keyboard': 4513,
#  'get': 3440,
#  'heating': 3735,
#  'pad': 5857,
#  'plus': 6165,
#  'two': 8566,
#  'dog': 2408,
#  'keep': 4501,
#  'company': 1560,
#  'one': 5681,
#  'randomly': 6595,
#  'rest': 6912,
#  'chin': 1332,
#  'leg': 4671,
#  'love': 4862,
#  'coworker': 1828,
#  'household': 3898,
#  'chore': 1345,
#  'do': 2392,
#  'today': 8370,
#  'exclamation': 2863,
#  'sure': 8034,
#  'restroom': 6920,
#  'quickly': 6550,
#  'return': 6945,
#  'enough': 2719,
#  'vacuum': 8823,
#  'dish': 2319,
#  'folk': 3182,
#  'rattle': 6620,
#  'meeting': 5068,
#  'lot': 4852,
#  'discipline': 2295,
#  'rough': 7041,
#  'first': 3101,
#  'week': 9059,
#  'easy': 2569,
#  'year': 9290,
#  'manage': 4940,
#  'morning': 5295,
#  'worry': 9236,
#  'important': 4060,
#  'yell': 9297,
#  'boss': 933,
#  'want': 8998,
#  'stay': 7836,
#  'yes': 9302,
#  'title': 8363,
#  'correct': 1779,
#  'nothing': 5553,
#  'translation': 8464,
#  'shut': 7428,
#  'fuck': 3309,
#  'rto': 7060,
#  'good': 3498,
#  'employee': 2673,
#  'find': 3080,
#  'fail': 2959,
#  'self': 7266,
#  'issue': 4386,
#  'look': 4833,
#  'associate': 495,
#  'art': 457,
#  'degree': 2093,
#  'rd': 6627,
#  'college': 1498,
#  'psych': 6466,
#  'major': 4924,
#  'full': 3320,
#  'hrs': 3914,
#  'exhausted': 2877,
#  'yeah': 9288,
#  'roughly': 7042,
#  'cap': 1156,
#  'somewhere': 7649,
#  'around': 449,
#  'month': 5282,
#  'thing': 8282,
#  'hit': 3818,
#  'peak': 5968,
#  'misery': 5204,
#  'genuinely': 3425,
#  'think': 8284,
#  'anything': 373,
#  'past': 5930,
#  'really': 6649,
#  'worth': 9241,
#  'free': 3260,
#  'beginning': 752,
#  'soul': 7661,
#  'also': 277,
#  'terrify': 8232,
#  'realize': 6648,
#  'advice': 158,
#  'command': 1528,
#  'decide': 2054,
#  'ask': 474,
#  'anyway': 375,
#  'wish': 9177,
#  'hope': 3865,
#  'enlighten': 2717,
#  'management': 4942,
#  'receive': 6670,
#  'prompt': 6423,
#  'act': 87,
#  'fact': 2953,
#  'north': 5538,
#  'korea': 4564,
#  'regular': 6743,
#  'election': 2624,
#  'mean': 5036,
#  'koreans': 4566,
#  'advise': 159,
#  'directly': 2275,
#  'even': 2816,
#  'mandate': 4947,
#  'you': 9317,
#  're': 6630,
#  'assume': 497,
#  'people': 5994,
#  'chance': 1267,
#  'entirely': 2733,
#  'opinion': 5711,
#  'rather': 6613,
#  'vision': 8926,
#  'functional': 3329,
#  'problem': 6376,
#  'solve': 7639,
#  'lease': 4656,
#  'perform': 6005,
#  'duty': 2542,
#  'should': 7411,
#  'not': 5548,
#  'burden': 1066,
#  'many': 4965,
#  'step': 7849,
#  'thousand': 8295,
#  'effort': 2606,
#  'since': 7469,
#  'short': 7400,
#  'workout': 9223,
#  'video': 8898,
#  'use': 8795,
#  'background': 627,
#  'noise': 5503,
#  'podcast': 6180,
#  'show': 7416,
#  've': 8849,
#  'watch': 9027,
#  'worker': 9214,
#  'beware': 787,
#  'we': 9038,
#  'entrepreneur': 2740,
#  'warn': 9011,
#  'philippines': 6057,
#  'latin': 4619,
#  'america': 306,
#  'pay': 5950,
#  'currently': 1944,
#  'occupation': 5624,
#  'cyber': 1968,
#  'still': 7868,
#  'field': 3053,
#  'certain': 1250,
#  'type': 8569,
#  'risk': 6994,
#  'security': 7247,
#  'normal': 5533,
#  'bank': 670,
#  'regional': 6739,
#  'grocery': 3577,
#  'store': 7890,
#  'place': 6121,
#  'fine': 3083,
#  'wife': 9141,
#  'employer': 2674,
#  'lie': 4719,
#  'that': 8257,
#  'll': 4782,
#  'someone': 7643,
#  'desperate': 2177,
#  'they': 8276,
#  'leave': 4661,
#  'soon': 7655,
#  'something': 7645,
#  'airline': 224,
#  'pilot': 6098,
#  'hour': 3893,
#  'catch': 1216,
#  'alien': 246,
#  'make': 4928,
#  'billion': 808,
#  'heavily': 3737,
#  'like': 4735,
#  'exactly': 2842,
#  'right': 6982,
#  'completely': 1586,
#  'unnecessary': 8707,
#  'definitely': 2089,
#  'morale': 5290,
#  'favorite': 3004,
#  'listen': 4760,
#  'almost': 267,
#  'always': 288,
#  'silence': 7450,
#  'lol': 4823,
#  'read': 6636,
#  'failure': 2960,
#  'oh': 5659,
#  'hypocrisy': 3974,
#  'twice': 8561,
#  'lunch': 4890,
#  'expense': 2894,
#  'call': 1124,
#  'team': 8164,
#  'rejection': 6760,
#  'start': 7818,
#  'experience': 2896,
#  'suck': 7979,
#  'be': 720,
#  'farmer': 2983,
#  'insurance': 4255,
#  'arrogant': 455,
#  'dick': 2226,
#  'high': 3783,
#  'shit': 7379,
#  'coke': 1480,
#  'every': 2823,
#  'blow': 871,
#  'mind': 5170,
#  'though': 8292,
#  'guess': 3600,
#  'everyone': 2826,
#  'understandable': 8637,
#  'overload': 5810,
#  'post': 6245,
#  'lead': 4644,
#  'forum': 3234,
#  'unusable': 8739,
#  'percentage': 5999,
#  'expect': 2891,
#  'actually': 99,
#  'covid': 1824,
#  'change': 1268,
#  'obvious': 5618,
#  'benefit': 774,
#  'thank': 8249,
#  'appreciate': 409,
#  'help': 3753,
#  'scam': 7158,
#  'real': 6641,
#  'representative': 6855,
#  'ss': 7775,
#  'info': 4169,
#  'bat': 705,
#  'career': 1183,
#  'recruiter': 6699,
#  'never': 5463,
#  'information': 4173,
#  'unless': 8693,
#  'fill': 3068,
#  'complete': 1585,
#  'exist': 2880,
#  'relatively': 6768,
#  'review': 6954,
#  'glassdoor': 3466,
#  'helpful': 3757,
#  'monitor': 5274,
#  'productivity': 6394,
#  'bare': 679,
#  'minimum': 5184,
#  'continue': 1715,
#  'bonus': 901,
#  'project': 6413,
#  'assignment': 491,
#  'deadline': 2032,
#  'interviewer': 4313,
#  'minute': 5194,
#  'impress': 4065,
#  'min': 5169,
#  'clip': 1422,
#  'brother': 1019,
#  'elite': 2641,
#  'interview': 4312,
#  'dragon': 2471,
#  'wake': 8982,
#  'eat': 2570,
#  'breakfast': 980,
#  'noon': 5528,
#  'play': 6136,
#  'yard': 9283,
#  'another': 355,
#  'enjoy': 2715,
#  'wells': 9077,
#  'fargo': 2981,
#  'dead': 2031,
#  'four': 3242,
#  'clock': 1424,
#  'wait': 8976,
#  'follow': 3183,
#  'story': 7893,
#  'manager': 4943,
#  'fire': 3093,
#  'productively': 6393,
#  'last': 4609,
#  'please': 6146,
#  'hate': 3690,
#  'medicaid': 5054,
#  'treatment': 8485,
#  'much': 5339,
#  'arise': 443,
#  'parttime': 5920,
#  'low': 4867,
#  'platform': 6134,
#  'desire': 2173,
#  'wrong': 9257,
#  'spend': 7713,
#  'tech': 8172,
#  'support': 8028,
#  'allot': 259,
#  'phone': 6064,
#  'getting': 3441,
#  'move': 5323,
#  'ex': 2839,
#  'husband': 3961,
#  'child': 1320,
#  'father': 2992,
#  'request': 6864,
#  'relocate': 6784,
#  'deny': 2138,
#  'amazing': 293,
#  'able': 10,
#  'money': 5258,
#  'raise': 6582,
#  'suddenly': 7984,
#  'bullshit': 1053,
#  'everything': 2827,
#  'trouble': 8509,
#  'senior': 7285,
#  'workforce': 9217,
#  'approach': 414,
#  'quit': 6555,
#  'less': 4695,
#  'shitty': 7387,
#  'seriously': 7306,
#  'production': 6391,
#  'idgaf': 3999,
#  'break': 977,
#  'sign': 7444,
#  'note': 5550,
#  'speak': 7689,
#  'different': 2238,
#  'hourly': 3894,
#  'staff': 7789,
#  'level': 4703,
#  'available': 584,
#  'block': 862,
#  'google': 3506,
#  'ai': 215,
#  'entail': 2724,
#  'term': 8223,
#  'offer': 5643,
#  'letter': 4700,
#  'clearly': 1402,
#  'state': 7825,
#  'doable': 2393,
#  'replacement': 6844,
#  'childcare': 1321,
#  'product': 6390,
#  'life': 4721,
#  'birthday': 823,
#  'come': 1517,
#  'second': 7238,
#  'absolutely': 20,
#  'gift': 3447,
#  'success': 7976,
#  'congrat': 1658,
#  'new': 5465,
#  'role': 7021,
#  'search': 7228,
#  'yet': 9306,
#  'optimistic': 5721,
#  'sale': 7112,
#  'excuse': 2867,
#  'culture': 1932,
#  'tax': 8149,
#  'incentive': 4088,
#  'bring': 1005,
#  'buy': 1092,
#  'neighborhood': 5441,
#  'clear': 1399,
#  'writing': 9256,
#  'spell': 7711,
#  'terminate': 8225,
#  'tell': 8199,
#  'file': 3065,
#  'live': 4771,
#  'anywhere': 377,
#  'sum': 8001,
#  'expensive': 2895,
#  'often': 5656,
#  'house': 3897,
#  'sometimes': 7647,
#  'end': 2689,
#  'food': 3189,
#  'position': 6236,
#  'decrease': 2065,
#  'legal': 4672,
#  'big': 800,
#  'stock': 7880,
#  'holder': 3830,
#  'extract': 2930,
#  'rent': 6826,
#  'space': 7677,
#  'building': 1045,
#  'cash': 1205,
#  'business': 1079,
#  'choice': 1340,
#  'secure': 7246,
#  'wild': 9148,
#  'obsess': 5611,
#  'canada': 1145,
#  'tho': 8289,
#  'steal': 7840,
#  'americans': 308,
#  'identity': 3998,
#  'fortune': 3233,
#  'doj': 2414,
#  'curious': 1940,
#  'layoff': 4637,
#  'within': 9184,
#  'roveremploye': 7050,
#  'know': 4554,
#  'admit': 138,
#  'solar': 7628,
#  'heck': 3739,
#  'outlier': 5776,
#  'old': 5669,
#  'man': 4939,
#  'recover': 6694,
#  'stroke': 7928,
#  'happen': 3665,
#  'ago': 202,
#  'lion': 4753,
#  'care': 1181,
#  'employ': 2671,
#  'disability': 2280,
#  'friendly': 3283,
#  'die': 2231,
#  'future': 3350,
#  'perspective': 6034,
#  'allow': 261,
#  'least': 4659,
#  'hybrid': 3965,
#  'working': 9220,
#  'option': 5724,
#  'learn': 4652,
#  'code': 1462,
#  'software': 7623,
#  'dev': 2203,
#  'difficult': 2242,
#  'town': 8420,
#  'visit': 8927,
#  'explain': 2905,
#  'away': 600,
#  'site': 7484,
#  'text': 8243,
#  'literally': 4765,
#  'accept': 41,
#  'total': 8407,
#  'salary': 7111,
#  'increase': 4110,
#  'deduct': 2069,
#  'cost': 1786,
#  'commute': 1552,
#  'whatever': 9098,
#  'rate': 6611,
#  'commuting': 1554,
#  'per': 5996,
#  'vehicle': 8856,
#  'bus': 1077,
#  'fare': 2980,
#  'add': 109,
#  'additional': 116,
#  'professional': 6397,
#  'wardrobe': 9004,
#  'doggy': 2411,
#  'daycare': 2017,
#  'applicable': 402,
#  'sound': 7663,
#  'young': 9318,
#  'age': 188,
#  'moneyk': 5263,
#  'cut': 1959,
#  'push': 6514,
#  'rental': 6827,
#  'utility': 8808,
#  'whether': 9109,
#  'account': 62,
#  'compensation': 1572,
#  'effective': 2601,
#  'satisfaction': 7139,
#  'couple': 1810,
#  'housemates': 3902,
#  'point': 6181,
#  'aside': 472,
#  'frequently': 3274,
#  'digital': 2248,
#  'nomad': 5505,
#  'must': 5366,
#  'satellite': 7137,
#  'wifi': 9142,
#  'narcissistic': 5393,
#  'personality': 6030,
#  'disorder': 2331,
#  'complain': 1582,
#  'whine': 9115,
#  'lazy': 4640,
#  'minus': 5193,
#  'true': 8516,
#  'reality': 6646,
#  'crappy': 1846,
#  'open': 5701,
#  'plan': 6125,
#  'awful': 602,
#  'part': 5907,
#  'brand': 967,
#  'floor': 3151,
#  'stare': 7816,
#  'talk': 8128,
#  'great': 3554,
#  'motivation': 5310,
#  'happy': 3672,
#  'hell': 3748,
#  'standard': 7806,
#  'necessary': 5420,
#  'thse': 8313,
#  'reduce': 6710,
#  'emission': 2658,
#  'baby': 615,
#  'restless': 6915,
#  'previous': 6336,
#  'active': 92,
#  'treadmill': 8482,
#  'foot': 3194,
#  'peddler': 5975,
#  'cheap': 1291,
#  'game': 3365,
#  'changer': 1269,
#  'pro': 6368,
#  'con': 1610,
#  'remotely': 6808,
#  'number': 5577,
#  'suspicion': 8056,
#  'knock': 4553,
#  'door': 2428,
#  'win': 9157,
#  'select': 7263,
#  'screening': 7205,
#  'pass': 5922,
#  'luck': 4879,
#  'car': 1172,
#  'ability': 9,
#  'already': 275,
#  'mention': 5089,
#  'can': 1144,
#  'physically': 6073,
#  'friend': 3282,
#  'workplace': 9224,
#  'kind': 4532,
#  'stick': 7861,
#  'depend': 2143,
#  'socially': 7612,
#  'pretty': 6330,
#  'introverted': 4323,
#  'alone': 268,
#  'thrive': 8306,
#  'distraction': 2363,
#  'kid': 4524,
#  'require': 6865,
#  'camera': 1136,
#  'nope': 5530,
#  'micromanage': 5128,
#  'verify': 8873,
#  'partner': 5918,
#  'chronically': 1353,
#  'ill': 4016,
#  'depressed': 2154,
#  'sob': 7600,
#  'loudly': 4857,
#  'focus': 3174,
#  'concrete': 1624,
#  'damn': 1987,
#  'quiet': 6551,
#  'hear': 3725,
#  'pain': 5861,
#  'hold': 3829,
#  'mom': 5249,
#  'anxiety': 366,
#  'struggle': 7935,
#  'crawl': 1851,
#  'wall': 8993,
#  'slip': 7542,
#  'loneliness': 4827,
#  'small': 7557,
#  'sneak': 7584,
#  'fun': 3327,
#  'close': 1428,
#  'ama': 289,
#  'mass': 4996,
#  'interested': 4282,
#  'principle': 6352,
#  'avoid': 591,
#  'taking': 8123,
#  'personal': 6029,
#  'conflict': 1647,
#  'unemployment': 8654,
#  'lose': 4847,
#  'bite': 828,
#  'bullet': 1052,
#  'dell': 2109,
#  'update': 8751,
#  'policy': 6190,
#  'exclude': 2864,
#  'fully': 3324,
#  'promotion': 6422,
#  'nah': 5381,
#  'solid': 7632,
#  'market': 4981,
#  'share': 7350,
#  'sphere': 7716,
#  'smart': 7559,
#  'telephone': 8195,
#  'compare': 1564,
#  'face': 2944,
#  'interaction': 4279,
#  'three': 8301,
#  'sub': 7950,
#  'suggest': 7993,
#  'random': 6594,
#  'scrolling': 7213,
#  'reply': 6847,
#  'adjust': 127,
#  'workload': 9222,
#  'other': 5757,
#  'stuff': 7941,
#  'crazy': 1854,
#  'unprofessional': 8718,
#  'firm': 3099,
#  'believer': 763,
#  'environment': 2745,
#  'sex': 7330,
#  'politic': 6195,
#  'religion': 6781,
#  'alot': 272,
#  'dye': 2544,
#  'hair': 3633,
#  'color': 1502,
#  'purple': 6506,
#  'pink': 6102,
#  'blue': 872,
#  'alteration': 279,
#  'appearance': 395,
#  'abide': 8,
#  'dress': 2486,
#  'grow': 3586,
#  'fast': 2989,
#  'otherwise': 5758,
#  'country': 1808,
#  'affiliate': 175,
#  'marketing': 4984,
#  'blessing': 855,
#  'bed': 737,
#  'forth': 3230,
#  'portable': 6224,
#  'external': 2927,
#  'may': 5023,
#  'side': 7437,
#  'kill': 4529,
#  'at': 508,
#  'hr': 3913,
#  'recruiting': 6700,
#  'become': 734,
#  'slew': 7534,
#  'unqualified': 8719,
#  'candidate': 1152,
#  'qualified': 6532,
#  'routine': 7047,
#  'maximise': 5020,
#  'crack': 1837,
#  'behind': 758,
#  'flexibility': 3138,
#  'advantage': 150,
#  'lay': 4635,
#  'priority': 6359,
#  'finding': 3082,
#  'reddit': 6706,
#  'center': 1240,
#  'relate': 6763,
#  'healthcare': 3721,
#  'probably': 6373,
#  'ok': 5664,
#  'except': 2853,
#  'train': 8441,
#  'properly': 6433,
#  'bitch': 825,
#  'slap': 7523,
#  'answer': 356,
#  'particular': 5914,
#  'wonderful': 9197,
#  'land': 4593,
#  'setup': 7322,
#  'pic': 6078,
#  'several': 7324,
#  'simulate': 7465,
#  'immature': 4035,
#  'response': 6908,
#  'sad': 7095,
#  'boat': 883,
#  'severance': 7325,
#  'hard': 3675,
#  'possibility': 6242,
#  'shortsighted': 7407,
#  'ceo': 1245,
#  'critical': 1882,
#  'error': 2773,
#  'honestly': 3854,
#  'fly': 3169,
#  'hang': 3662,
#  'occasion': 5620,
#  'inconvenience': 4105,
#  'actual': 97,
#  'turn': 8548,
#  'base': 693,
#  'games': 3368,
#  'farm': 2982,
#  'run': 7072,
#  'tip': 8356,
#  'ranting': 6599,
#  'mad': 4905,
#  'alarm': 235,
#  'bear': 723,
#  'wealth': 9041,
#  'kinda': 4533,
#  'happiness': 3671,
#  'bud': 1035,
#  'cat': 1213,
#  'cover': 1819,
#  'damage': 1985,
#  'control': 1728,
#  'debacle': 2041,
#  'forgiveness': 3217,
#  'income': 4099,
#  'asap': 466,
#  'idea': 3992,
#  'survey': 8049,
#  'online': 5688,
#  'sell': 7274,
#  'premium': 6302,
#  'linkedin': 4751,
#  'surprise': 8042,
#  'gross': 3580,
#  'plenty': 6151,
#  'woman': 9195,
#  'seem': 7256,
#  'comparable': 1562,
#  'content': 1706,
#  'little': 4769,
#  'practice': 6273,
#  'healthy': 3723,
#  'habit': 3621,
#  'force': 3201,
#  'discover': 2305,
#  'spin': 7722,
#  'cycle': 1971,
#  'sane': 7130,
#  'lost': 4851,
#  'choose': 1341,
#  'mining': 5185,
#  'beneficial': 773,
#  'reveal': 6949,
#  'secret': 7241,
#  'vacation': 8820,
#  'without': 9185,
#  'responsibility': 6909,
#  'respond': 6905,
#  'done': 2422,
#  'actively': 93,
#  'worst': 9240,
#  'forget': 3215,
#  'mute': 5369,
#  'moment': 5250,
#  'headphone': 3713,
#  'extremely': 2934,
#  'upset': 8762,
#  'mainly': 4920,
#  'bc': 717,
#  'asinine': 473,
#  'unfair': 8659,
#  'to': 8367,
#  'local': 4800,
#  'stipend': 7876,
#  'combination': 1513,
#  'entitlement': 2737,
#  'lack': 4583,
#  'ethic': 2799,
#  'awareness': 599,
#  'seems': 7258,
#  'rampant': 6590,
#  'group': 3584,
#  'red': 6704,
#  'flag': 3122,
#  'thought': 8293,
#  'virtual': 8917,
#  'coffee': 1465,
#  'chat': 1284,
#  'program': 6406,
#  'connect': 1663,
#  'casual': 1210,
#  'chime': 1331,
#  'optional': 5725,
#  'mandatory': 4948,
#  'socializing': 7611,
#  'cringe': 1875,
#  'grant': 3543,
#  'tired': 8358,
#  'stigma': 7867,
#  'war': 9003,
#  'unreal': 8720,
#  'cause': 1223,
#  'lady': 4585,
#  'department': 2141,
#  'spray': 7752,
#  'air': 220,
#  'fog': 3177,
#  'bug': 1040,
#  'apparently': 391,
#  'germ': 3436,
#  'flu': 3159,
#  'season': 7231,
#  'ever': 2822,
#  'ediscovery': 2588,
#  'law': 4630,
#  'road': 7001,
#  'map': 4966,
#  'comfy': 1524,
#  'usually': 8804,
#  'nap': 5388,
#  'whole': 9124,
#  'interval': 4309,
#  'exercise': 2874,
#  'energy': 2702,
#  'super': 8015,
#  'busy': 1083,
#  'bit': 824,
#  'tv': 8555,
#  'street': 7912,
#  'drug': 2510,
#  'beta': 784,
#  'sentence': 7293,
#  'rise': 6992,
#  'dual': 2517,
#  'maket': 4930,
#  'finance': 3077,
#  'zoom': 9340,
#  'outside': 5787,
#  'resource': 6897,
#  'understand': 8636,
#  'agree': 205,
#  'expectation': 2892,
#  'favor': 3002,
#  'loose': 4842,
#  'join': 4456,
#  'fake': 2966,
#  'name': 5386,
#  'kick': 4519,
#  'invite': 4346,
#  'childish': 1324,
#  'girlfriend': 3453,
#  'beck': 733,
#  'communicate': 1546,
#  'positive': 6237,
#  'gentle': 3421,
#  'value': 8834,
#  'drive': 2496,
#  'productive': 6392,
#  'reaction': 6634,
#  'amazon': 295,
#  'world': 9231,
#  'walker': 8989,
#  'top': 8399,
#  'refer': 6716,
#  'mr': 5331,
#  'mrs': 5332,
#  'legit': 4678,
#  'meet': 5067,
#  'mike': 5151,
#  'scammer': 7160,
#  'overly': 5813,
#  'formal': 3222,
#  'physical': 6072,
#  'going': 3492,
#  'hurt': 3960,
#  'us': 8784,
#  'ignore': 4010,
#  'rule': 7069,
#  'chick': 1317,
#  'director': 2276,
#  'clinical': 1420,
#  'lpt': 4877,
#  'schedule': 7178,
#  'offline': 5650,
#  'fairly': 2962,
#  'however': 3909,
#  'exact': 2841,
#  'recently': 6672,
#  'shower': 7418,
#  'difference': 2237,
#  'medicine': 5060,
#  'specifically': 7703,
#  'eye': 2937,
#  'bs': 1028,
#  'biology': 817,
#  'forward': 3235,
#  'opening': 5703,
#  'andor': 326,
#  'admin': 131,
#  'steady': 7838,
#  'let': 4698,
#  'hand': 3648,
#  'medium': 5065,
#  'consume': 1698,
#  'nyt': 5590,
#  'article': 459,
#  'pandemic': 5873,
#  'include': 4096,
#  'nyc': 5589,
#  'finally': 3076,
#  ...}

# %%
from sklearn.pipeline import Pipeline
from sklearn.feature_selection import SelectKBest, chi2  # Import SelectKBest and chi2
from sklearn.feature_extraction.text import TfidfTransformer, CountVectorizer
from sklearn.svm import LinearSVC

opt_pipeline = Pipeline([
    ('sel', SelectKBest(chi2)),  # feature selection
    ('tfidf', TfidfTransformer()),  # weighting
    ('learner', LinearSVC())  # learning algorithm
])

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import loguniform  

budget = 10

r_param_grid = [
    {'sel__k': [200, 1000, 2000, 3000, 4000, 'all'], 'learner__C': loguniform(0.01, 100)},  
]

optr_search = RandomizedSearchCV(opt_pipeline, r_param_grid, cv=5, n_iter=budget, n_jobs=3, verbose=True).fit(X_train_tok, y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits

# %%
optr_search.best_params_
# Out:
# {'learner__C': 2.6087754300783432, 'sel__k': 3000}

# %%
X_test_tok
# Out:
# <22289x9344 sparse matrix of type '<class 'numpy.int64'>'
# 	with 422187 stored elements in Compressed Sparse Row format>

# %%
optr_predictions = optr_search.best_estimator_.predict(X_test_tok)

from sklearn.metrics import classification_report, accuracy_score

print(f"Accuracy: {accuracy_score(y_test, optr_predictions)}")

print("Classification Report:")
print(classification_report(y_test, optr_predictions))
# Out:
# Accuracy: 0.7771995154560546
# Classification Report:
#               precision    recall  f1-score   support
#
#        anger       0.72      0.51      0.60      3296
#         fear       0.67      0.39      0.49      1155
#          joy       0.80      0.93      0.86     13353
#         love       0.73      0.40      0.51       164
#      sadness       0.76      0.63      0.69      4008
#     surprise       0.76      0.68      0.72       313
#
#     accuracy                           0.78     22289
#    macro avg       0.74      0.59      0.64     22289
# weighted avg       0.77      0.78      0.76     22289

# %% [markdown]
# ## Non-linear SVM

# %%
from sklearn.svm import SVC

# create the pipeline with SVM and linear kernel
opt_pipeline_linear = Pipeline([
    ('sel', SelectKBest(chi2)),  # feature selection
    ('tfidf', TfidfTransformer()),  # weighting
    ('learner', SVC(kernel='linear'))  
])

# define the parameter grid for RandomizedSearchCV
r_param_grid_linear = [
    {'sel__k': [2000, 3000], 
     'learner__C': loguniform(0.01, 100),  # C parameter of the SVM
     'learner__gamma': ['scale', 'auto']}  
]

# %%
budget = 2  
optr_search_linear= RandomizedSearchCV(opt_pipeline_linear, r_param_grid_linear, cv=2, n_iter=budget, n_jobs=-1, verbose=True)
optr_search_linear.fit(X_train_tok, y_train)

best_model_linear = optr_search_linear.best_estimator_
# Out:
# Fitting 2 folds for each of 2 candidates, totalling 4 fits

# %%
optr_search_linear.best_params_
# Out:
# {'learner__C': 0.27976480806881115, 'learner__gamma': 'auto', 'sel__k': 3000}

# %%
y_pred_linear = best_model_linear.predict(X_test_tok)
print(f"Accuracy: {accuracy_score(y_test, y_pred_linear)}")

print("Classification Report:")
print(classification_report(y_test, y_pred_linear))
# Out:
# Accuracy: 0.7391538427026785
# Classification Report:
#               precision    recall  f1-score   support
#
#        anger       0.72      0.37      0.49      3296
#         fear       0.68      0.20      0.31      1155
#          joy       0.74      0.95      0.83     13353
#         love       0.64      0.26      0.37       164
#      sadness       0.78      0.53      0.63      4008
#     surprise       0.78      0.52      0.62       313
#
#     accuracy                           0.74     22289
#    macro avg       0.72      0.47      0.54     22289
# weighted avg       0.74      0.74      0.71     22289
