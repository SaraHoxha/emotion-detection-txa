# %%
import pandas as pd

# %%
data = pd.read_csv('train_t5.csv')

# %%
data.head()
# Out:
#                                                 text    label
# 0  Does anyone use their own computer question as...      joy
# 1  WFH is getting to be...ehhhh. thats not even a...      joy
# 2  everything is awesome …Are annual employee sat...      joy
# 3  Remote Workers Beware: US Entrepreneur Warns  ...     fear
# 4  Teams & Slack Users: Please just ask the quest...  sadness

# %%
label_counts = data['label'].value_counts()
label_counts
# Out:
# label
# joy         43463
# anger       29667
# fear        12054
# sadness     11217
# surprise     1008
# love          487
# Name: count, dtype: int64

# %%
import spacy
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk import download

# %%
# Download necessary NLTK resources
download('punkt')  # For tokenization
download('stopwords')  # For stopwords

# Load SpaCy English model
nlp = spacy.load("en_core_web_sm")
# Out:
# [nltk_data] Downloading package punkt to C:\Users\minhd/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\minhd/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def preprocess_text(text):
    # lowercase 
    text = text.lower()

    tokens = word_tokenize(text)

    # remove stopwords
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word.isalpha() and word not in stop_words]

    # lemmatization (using SpaCy)
    doc = nlp(" ".join(tokens))
    lemmatized_tokens = [token.lemma_ for token in doc]

    # return to string 
    return " ".join(lemmatized_tokens)

# %%
data['processed_text'] = data['text'].apply(preprocess_text)

# %%
data
# Out:
#                                                     text    label  \
# 0      Does anyone use their own computer question as...      joy
# 1      WFH is getting to be...ehhhh. thats not even a...      joy
# 2      everything is awesome …Are annual employee sat...      joy
# 3      Remote Workers Beware: US Entrepreneur Warns  ...     fear
# 4      Teams & Slack Users: Please just ask the quest...  sadness
# ...                                                  ...      ...
# 97891   money20k for 2 days per week in office or sta...      joy
# 97892  RTO and Environmemtalism i'm even game for reg...    anger
# 97893  What purchase have you made that’s made a big ...     fear
# 97894  Why are people obsessed with return to office ...     love
# 97895  My biggest gripe is people who just message yo...    anger
#
#                                           processed_text
# 0      anyone use computer question remote software e...
# 1      wfh get ehhhh that s even downside good part s...
# 2      everything awesome annual employee satisfactio...
# 3      remote worker beware we entrepreneur warn work...
# 4      team slack user please ask question stop leave...
# ...                                                  ...
# 97891  day per week office stay remote question way s...
# 97892  rto environmemtalism even game regional requir...
# 97893  purchase make make big impact wfh environment ...
# 97894  people obsess return office question question ...
# 97895  big gripe people message team say hi question ...
#
# [97896 rows x 3 columns]

# %%
test_data = pd.read_csv('test_t5.csv')

# %%
test_data['processed_text'] = test_data['text'].apply(preprocess_text)

# %%
test_data
# Out:
#                                                     text  label  \
# 0      Winter Blues and WFH question i think the sudd...  anger
# 1      New Workspace i saw some of your other posts a...    joy
# 2      Hard to mentally unwind… i go for a long walk ...    joy
# 3      Would you leave 150k for 90k depends on your e...    joy
# 4      There’s no magic formula to get remote work so...   fear
# ...                                                  ...    ...
# 24469  My biggest gripe is people who just message yo...  anger
# 24470  WFH exception denied caregiving that requires ...  anger
# 24471  Would you take  money15k less/year for WFH que...    joy
# 24472  “Losers question” yeah frey has been a shithea...  anger
# 24473  My home office I set up in the garage. 49 inch...   fear
#
#                                           processed_text
# 0      winter blue wfh question think sudden shift bu...
# 1      new workspace see post renovation go incredibl...
# 2      hard mentally go long walk work help shift wor...
# 3                      would leave depend expense saving
# 4      magic formula get remote work worry nothing go...
# ...                                                  ...
# 24469  big gripe people message team say hi question ...
# 24470  wfh exception deny caregiving require home kin...
# 24471  would take wfh question yes grad school put fo...
# 24472   loser question yeah frey shithead long time late
# 24473  home office set garage inch monitor inch tv tv...
#
# [24474 rows x 3 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
from sklearn.metrics import classification_report

X_train = data['processed_text']
y_train = data['label']

X_test = test_data['processed_text']
y_test = test_data['label']

# %%
import time
from sklearn.feature_extraction.text import CountVectorizer  # Import CountVectorizer

start_time = time.time()
# vect = CountVectorizer()  # Convert a collection of text documents to a matrix of token counts.
vect = CountVectorizer(min_df=5)  # Convert a collection of text documents to a matrix of token counts.

print('fit')
vect.fit(X_train)

print('transform') # actual counting
X_train_tok = vect.transform(X_train)

end_time = time.time()
print('done')

# The two steps above can be condensed in a single step that processes train
# data only once.

X_test_tok = vect.transform(X_test)
# Out:
# fit
# transform
# done

# %%
elapsed_time = end_time - start_time
print(f"Time employed: {elapsed_time:.2f} seconds")
len(vect.vocabulary_)
# Out:
# Time employed: 4.49 seconds
# 9760

# %%
vect.vocabulary_
# Out:
# {'anyone': 395,
#  'use': 9190,
#  'computer': 1701,
#  'question': 6833,
#  'remote': 7105,
#  'software': 7951,
#  'engineer': 2865,
#  'absolutely': 23,
#  'believe': 803,
#  'invest': 4566,
#  'ideal': 4214,
#  'hardware': 3889,
#  'office': 5911,
#  'since': 7789,
#  'company': 1651,
#  'issue': 4612,
#  'laptop': 4837,
#  'still': 8205,
#  'desk': 2306,
#  'can': 1214,
#  'imagine': 4253,
#  'work': 9621,
#  'wfh': 9501,
#  'get': 3642,
#  'ehhhh': 2766,
#  'that': 8621,
#  'even': 2978,
#  'downside': 2596,
#  'good': 3706,
#  'part': 6174,
#  'see': 7574,
#  'people': 6263,
#  'bad': 671,
#  'interact': 4506,
#  'do': 2530,
#  'not': 5807,
#  'care': 1253,
#  'everything': 2989,
#  'awesome': 632,
#  'annual': 370,
#  'employee': 2827,
#  'satisfaction': 7457,
#  'survey': 8401,
#  'really': 6938,
#  'anonymous': 375,
#  'move': 5580,
#  'internally': 4523,
#  'find': 3258,
#  'worker': 9627,
#  'beware': 830,
#  'we': 9451,
#  'entrepreneur': 2899,
#  'warn': 9421,
#  'philippines': 6331,
#  'latin': 4853,
#  'america': 323,
#  'well': 9483,
#  'job': 4671,
#  'probably': 6657,
#  'willing': 9564,
#  'money': 5510,
#  'hour': 4115,
#  'team': 8522,
#  'slack': 7844,
#  'user': 9194,
#  'please': 6422,
#  'ask': 499,
#  'stop': 8227,
#  'leave': 4898,
#  'empty': 2831,
#  'greeting': 3774,
#  'exclamation': 3027,
#  'hey': 3990,
#  'long': 5075,
#  'time': 8705,
#  'july': 4715,
#  'th': 8612,
#  'weekend': 9473,
#  'need': 5684,
#  'veteran': 9287,
#  'va': 9213,
#  'fully': 3520,
#  'type': 8947,
#  'skill': 7825,
#  'learn': 4888,
#  'train': 8814,
#  'assume': 525,
#  'you': 9731,
#  're': 6919,
#  'yeah': 9703,
#  'go': 3687,
#  'hard': 3885,
#  'employer': 2828,
#  'monitor': 5531,
#  'productivity': 6679,
#  'bridge': 1056,
#  'maintenance': 5169,
#  'take': 8475,
#  'year': 9705,
#  'easy': 2720,
#  'career': 1255,
#  'almost': 281,
#  'cover': 1933,
#  'thing': 8646,
#  'lot': 5099,
#  'make': 5174,
#  'assumption': 527,
#  'try': 8898,
#  'think': 8648,
#  'scamme': 7478,
#  'hope': 4085,
#  'scam': 7477,
#  'never': 5723,
#  'front': 3484,
#  'check': 1369,
#  'purchase': 6788,
#  'equipment': 2925,
#  'also': 292,
#  'legitimate': 4920,
#  'would': 9659,
#  'hire': 4028,
#  'solely': 7958,
#  'email': 2802,
#  'correspondence': 1892,
#  'text': 8606,
#  'setup': 7644,
#  'put': 6806,
#  'website': 9467,
#  'otherwise': 6028,
#  'seem': 7580,
#  'pay': 6218,
#  'dollar': 2554,
#  'jean': 4650,
#  'day': 2142,
#  'somewhat': 7975,
#  'indianapoli': 4352,
#  'pretty': 6616,
#  'reasonable': 6946,
#  'little': 5015,
#  'moneyday': 5512,
#  'sometimes': 7974,
#  'one': 5952,
#  'percentage': 6269,
#  'expect': 3058,
#  'actually': 107,
#  'something': 7972,
#  'like': 4982,
#  'week': 9471,
#  'without': 9597,
#  'say': 7472,
#  'anything': 397,
#  've': 9249,
#  'much': 5598,
#  'free': 3453,
#  'adult': 156,
#  'life': 4968,
#  'feel': 3204,
#  'cheat': 1367,
#  'code': 1550,
#  'finally': 3253,
#  'enjoy': 2870,
#  'roll': 7340,
#  'bed': 776,
#  'chair': 1332,
#  'adjustable': 136,
#  'frame': 3441,
#  'game': 3566,
#  'changer': 1341,
#  'sleep': 7853,
#  'lower': 5114,
#  'back': 652,
#  'comfy': 1615,
#  'forever': 3402,
#  'wake': 9389,
#  'lol': 5068,
#  'zoom': 9757,
#  'fatigue': 3173,
#  'remedy': 7097,
#  'comment': 1620,
#  'meeting': 5317,
#  'interested': 4511,
#  'single': 7795,
#  'dad': 2103,
#  'idea': 4213,
#  'keep': 4735,
#  'kid': 4760,
#  'entertain': 2884,
#  'seriously': 7630,
#  'nuts': 5846,
#  'insist': 4445,
#  'homeschooling': 4067,
#  'drop': 2647,
#  'house': 4118,
#  'school': 7502,
#  'childcare': 1395,
#  'always': 303,
#  'fireable': 3273,
#  'offense': 5907,
#  'everywhere': 2991,
#  'pass': 6190,
#  'sick': 7755,
#  'holiday': 4053,
#  'room': 7349,
#  'fast': 3167,
#  'learner': 4889,
#  'someone': 7970,
#  'give': 3661,
#  'chance': 1339,
#  'way': 9447,
#  'wild': 9559,
#  'want': 9407,
#  'figure': 3239,
#  'provide': 6744,
#  'value': 9231,
#  'getting': 3643,
#  'todo': 8741,
#  'business': 1146,
#  'owner': 6110,
#  'risk': 7310,
#  'capital': 1233,
#  'talk': 8485,
#  'phone': 6337,
#  'often': 5923,
#  'basic': 732,
#  'task': 8501,
#  'nothing': 5814,
#  'another': 376,
#  'country': 1921,
#  'to': 8735,
#  'face': 3115,
#  'fact': 3124,
#  'field': 3230,
#  'abundant': 30,
#  'reality': 6935,
#  'disappear': 2419,
#  'look': 5079,
#  'low': 5111,
#  'common': 1633,
#  'denominator': 2262,
#  'bottom': 992,
#  'barrel': 722,
#  'basically': 733,
#  'exist': 3046,
#  'tier': 8694,
#  'rto': 7377,
#  'announce': 364,
#  'today': 8738,
#  'disable': 2415,
#  'consider': 1772,
#  'suicide': 8342,
#  'request': 7169,
#  'ada': 112,
#  'exemption': 3039,
#  'correct': 1887,
#  'accommodation': 57,
#  'spend': 8045,
#  'anywhere': 401,
#  'depend': 2273,
#  'freelance': 3456,
#  'sound': 7991,
#  'industry': 4371,
#  'other': 6027,
#  'search': 7549,
#  'education': 2746,
#  'experience': 3064,
#  'location': 5047,
#  'stuff': 8281,
#  'legit': 4918,
#  'concentrate': 1706,
#  'scammer': 7479,
#  'know': 4791,
#  'entry': 2901,
#  'level': 4947,
#  'prioritize': 6642,
#  'literally': 5011,
#  'aspect': 504,
#  'qualified': 6820,
#  'min': 5420,
#  'start': 8154,
#  'allow': 275,
#  'possibly': 6522,
#  'role': 7339,
#  'difference': 2371,
#  'building': 1110,
#  'center': 1313,
#  'tell': 8563,
#  'folk': 3369,
#  'later': 4851,
#  'absorb': 24,
#  'member': 5327,
#  'end': 2844,
#  'date': 2133,
#  'eventually': 2983,
#  'let': 4942,
#  'around': 475,
#  'indicator': 4357,
#  'bs': 1092,
#  'prior': 6640,
#  'responsible': 7217,
#  'client': 1497,
#  'system': 8461,
#  'production': 6676,
#  'specific': 8034,
#  'hook': 4081,
#  'moneyk': 5517,
#  'cash': 1280,
#  'performance': 6275,
#  'penalty': 6254,
#  'deliver': 2236,
#  'early': 2707,
#  'avoid': 624,
#  'lay': 4870,
#  'less': 4937,
#  'everyone': 2988,
#  'utopia': 9207,
#  'interview': 4541,
#  'mention': 5338,
#  'camera': 1206,
#  'activity': 103,
#  'device': 2340,
#  'nonsense': 5779,
#  'fail': 3132,
#  'understand': 9018,
#  'place': 6394,
#  'clue': 1528,
#  'metric': 5363,
#  'confirm': 1742,
#  'month': 5539,
#  'certification': 1327,
#  'could': 1908,
#  'online': 5959,
#  'home': 4056,
#  'base': 726,
#  'travel': 8848,
#  'agent': 206,
#  'love': 5107,
#  'flexible': 3323,
#  'attire': 565,
#  'wear': 9457,
#  'usually': 9199,
#  'shower': 7738,
#  'shy': 7751,
#  'pjs': 6391,
#  'bra': 1009,
#  'duty': 2692,
#  'sure': 8383,
#  'professional': 6681,
#  'handsome': 3868,
#  'coworker': 1941,
#  'steal': 8179,
#  'course': 1927,
#  'mad': 5150,
#  'ever': 2984,
#  'yell': 9712,
#  'shortsighted': 7728,
#  'tech': 8530,
#  'ceo': 1319,
#  'critical': 1995,
#  'error': 2937,
#  'offshore': 5920,
#  'effective': 2753,
#  'right': 7297,
#  'resource': 7202,
#  'difficult': 2376,
#  'run': 7390,
#  'couple': 1924,
#  'correctly': 1889,
#  'stand': 8138,
#  'nice': 5739,
#  'style': 8291,
#  'lack': 4819,
#  'quite': 6845,
#  'bit': 867,
#  'lighting': 4979,
#  'eye': 3108,
#  'head': 3915,
#  'hurt': 4181,
#  'working': 9632,
#  'non': 5769,
#  'apply': 430,
#  'exactly': 3003,
#  'network': 5716,
#  'event': 2981,
#  'translation': 8835,
#  'shut': 7749,
#  'fuck': 3504,
#  'california': 1190,
#  'government': 3727,
#  'play': 6411,
#  'penalize': 6253,
#  'bring': 1063,
#  'downtown': 2601,
#  'area': 460,
#  'cater': 1293,
#  'absurd': 26,
#  'vote': 9356,
#  'authoritarian': 595,
#  'micromanage': 5380,
#  'every': 2985,
#  'debate': 2168,
#  'odd': 5897,
#  'many': 5211,
#  'sub': 8293,
#  'productive': 6677,
#  'mental': 5335,
#  'health': 3930,
#  'socialize': 7937,
#  'hi': 3991,
#  'minute': 5444,
#  'rd': 6917,
#  'tuesday': 8909,
#  'world': 9644,
#  'cell': 1308,
#  'knowledge': 4795,
#  'cook': 1850,
#  'spaghetti': 8010,
#  'new': 5726,
#  'mom': 5501,
#  'full': 3515,
#  'sneak': 7910,
#  'peek': 6246,
#  'top': 8766,
#  'post': 6523,
#  'humble': 4158,
#  'brag': 1012,
#  'fkn': 3300,
#  'college': 1588,
#  'turn': 8923,
#  'sunday': 8354,
#  'bot': 989,
#  'beep': 783,
#  'boop': 969,
#  'downvote': 2603,
#  'remove': 7120,
#  'contact': 1800,
#  'info': 4395,
#  'optout': 5996,
#  'github': 3659,
#  'anybody': 392,
#  'else': 2799,
#  'partner': 6185,
#  'ampm': 333,
#  'joke': 4688,
#  'whenever': 9517,
#  'be': 754,
#  'case': 1278,
#  'half': 3843,
#  'prefer': 6575,
#  'offer': 5909,
#  'except': 3015,
#  'indians': 4353,
#  'fraction': 3438,
#  'counterpart': 1917,
#  'will': 9562,
#  'relocate': 7088,
#  'though': 8656,
#  'advice': 169,
#  'likely': 4985,
#  'economic': 2730,
#  'development': 2339,
#  'either': 2768,
#  'accept': 44,
#  'ed': 2736,
#  'tax': 8508,
#  'break': 1033,
#  'agree': 217,
#  'amount': 329,
#  'fte': 3500,
#  'wage': 9375,
#  'gpt': 3730,
#  'great': 3763,
#  'especially': 2945,
#  'highlevel': 4003,
#  'detail': 2320,
#  'instantly': 4463,
#  'raise': 6872,
#  'rate': 6899,
#  'graduate': 3736,
#  'video': 9300,
#  'call': 1193,
#  'normal': 5794,
#  'big': 843,
#  'brother': 1080,
#  'definitely': 2219,
#  'watch': 9437,
#  'org': 6007,
#  'yrs': 9739,
#  'become': 773,
#  'unhealthy': 9056,
#  'joint': 4687,
#  'circulation': 1444,
#  'stay': 8173,
#  'lookin': 5080,
#  'busy': 1150,
#  'jackass': 4626,
#  'representative': 7158,
#  'write': 9669,
#  'legislation': 4915,
#  'entire': 2891,
#  'increase': 4335,
#  'wah': 9378,
#  'covid': 1937,
#  'miss': 5460,
#  'due': 2669,
#  'force': 3389,
#  'ignorant': 4231,
#  'politician': 6473,
#  'require': 7170,
#  'associate': 523,
#  'embarrassed': 2804,
#  'undoubtedly': 9034,
#  'person': 6298,
#  'insert': 4439,
#  'proverbial': 6743,
#  'boomer': 966,
#  'proud': 6741,
#  'abysmal': 34,
#  'poor': 6490,
#  'soul': 7989,
#  'forget': 3404,
#  'impossible': 4287,
#  'four': 3434,
#  'send': 7608,
#  'application': 428,
#  'luck': 5123,
#  'onsite': 5962,
#  'regular': 7046,
#  'economy': 2733,
#  'threaten': 8663,
#  'quit': 6844,
#  'amazon': 310,
#  'demand': 2245,
#  'return': 7252,
#  'five': 3293,
#  'contractor': 1818,
#  'badge': 673,
#  'gate': 3585,
#  'open': 5971,
#  'elevator': 2790,
#  'log': 5056,
#  'inout': 4427,
#  'lunch': 5134,
#  'surprised': 8394,
#  'resentful': 7182,
#  'support': 8376,
#  'corporate': 1882,
#  'real': 6930,
#  'estate': 2954,
#  'market': 5227,
#  'waiting': 9384,
#  'speak': 8020,
#  'boss': 986,
#  'come': 1608,
#  'typical': 8950,
#  'involve': 4577,
#  'intellectual': 4493,
#  'ability': 10,
#  'ai': 227,
#  'mentally': 5337,
#  'gripe': 3786,
#  'message': 5352,
#  'here': 3981,
#  'annoying': 369,
#  'aol': 402,
#  'messenger': 5354,
#  'rave': 6909,
#  'wonder': 9610,
#  'block': 909,
#  'basis': 734,
#  'depressed': 2286,
#  'flex': 3321,
#  'hrs': 4136,
#  'tip': 8723,
#  'planning': 6403,
#  'remotely': 7111,
#  'concur': 1720,
#  'thank': 8614,
#  'inform': 4396,
#  'might': 5399,
#  'source': 7997,
#  'distraction': 2501,
#  'must': 5625,
#  'separate': 7620,
#  'certainly': 1325,
#  'waste': 9433,
#  'two': 8942,
#  'wow': 9662,
#  'informative': 4400,
#  'share': 7671,
#  'consistently': 1780,
#  'parttime': 6187,
#  'extra': 3099,
#  'income': 4322,
#  'slow': 7875,
#  'datum': 2134,
#  'first': 3280,
#  'press': 6607,
#  'shift': 7693,
#  'delete': 2229,
#  'everytime': 2990,
#  'already': 290,
#  'sacrifice': 7412,
#  'advancement': 161,
#  'remain': 7092,
#  'freedom': 3454,
#  'price': 6625,
#  'live': 5017,
#  'northern': 5800,
#  'region': 7039,
#  'deal': 2159,
#  'dark': 2123,
#  'ahead': 223,
#  'indoor': 4367,
#  'close': 1512,
#  'comfortable': 1613,
#  'ski': 7824,
#  'golf': 3702,
#  'nearby': 5675,
#  'favorite': 3181,
#  'midday': 5388,
#  'winter': 9578,
#  'snow': 7921,
#  'outside': 6056,
#  'rent': 7130,
#  'mandate': 5193,
#  'jesus': 4658,
#  'human': 4155,
#  'treat': 8854,
#  'slave': 7851,
#  'show': 7736,
#  'bank': 703,
#  'account': 66,
#  'research': 7178,
#  'ban': 696,
#  'notice': 5815,
#  'subreddit': 8302,
#  'op': 5970,
#  'state': 8161,
#  'filipino': 3244,
#  'help': 3966,
#  'explain': 3074,
#  'situation': 7811,
#  'simple': 7781,
#  'google': 3715,
#  'philippine': 6330,
#  'peso': 6309,
#  'wish': 9589,
#  'white': 9532,
#  'board': 929,
#  'webex': 9464,
#  'whiteboard': 9533,
#  'interactive': 4508,
#  'outlier': 6045,
#  'approve': 442,
#  'congrat': 1755,
#  'ppl': 6548,
#  'healthcare': 3931,
#  'yup': 9744,
#  'boatload': 933,
#  'serious': 7629,
#  'hold': 4049,
#  'walk': 9394,
#  'away': 630,
#  'handle': 3863,
#  'pm': 6445,
#  'intense': 4498,
#  'lie': 4966,
#  'hotspot': 4113,
#  'somebody': 7967,
#  'public': 6767,
#  'original': 6019,
#  'son': 7977,
#  'law': 4865,
#  'rural': 7394,
#  'texas': 8605,
#  'recently': 6961,
#  'nyc': 5853,
#  'lousy': 5106,
#  'internet': 4526,
#  'cheap': 1365,
#  'tiny': 8722,
#  'town': 8787,
#  'version': 9281,
#  'story': 8232,
#  'lead': 4880,
#  'happiness': 3881,
#  'micromanagement': 5381,
#  'awful': 633,
#  'happy': 3882,
#  'breathe': 1046,
#  'neck': 5682,
#  'welcome': 9481,
#  'supportive': 8378,
#  'super': 8362,
#  'important': 4284,
#  'opinion': 5982,
#  'animal': 358,
#  'background': 658,
#  'virtual': 9321,
#  'suggestion': 8340,
#  'hmm': 4040,
#  'quote': 6850,
#  'razor': 6912,
#  'attribute': 571,
#  'adequately': 128,
#  'stupidity': 8287,
#  'read': 6924,
#  'south': 7999,
#  'current': 2063,
#  'tomorrow': 8757,
#  'last': 4844,
#  'problem': 6660,
#  'mostly': 5559,
#  'able': 11,
#  'access': 48,
#  'cry': 2025,
#  'hate': 3900,
#  'darkness': 2124,
#  'negotiate': 5698,
#  'gather': 3589,
#  'project': 6700,
#  'finish': 3265,
#  'key': 4747,
#  'stroke': 8268,
#  'click': 1493,
#  'mouse': 5576,
#  'recording': 6983,
#  'screen': 7524,
#  'active': 100,
#  'status': 8171,
#  'may': 5270,
#  'toe': 8742,
#  'line': 4992,
#  'decline': 2188,
#  'opportunity': 5984,
#  'relentlessly': 7077,
#  'loosen': 5090,
#  'fluorescent': 3352,
#  'light': 4977,
#  'buzz': 1164,
#  'noise': 5766,
#  'stupid': 8286,
#  'small': 7882,
#  'mile': 5406,
#  'actual': 105,
#  'city': 1455,
#  'twice': 8936,
#  'radon': 6864,
#  'test': 8599,
#  'high': 3998,
#  'number': 5837,
#  'basement': 730,
#  'build': 1108,
#  'nw': 5850,
#  'iowa': 4582,
#  'old': 5936,
#  'lose': 5094,
#  'die': 2365,
#  'accident': 52,
#  'cancer': 1221,
#  'young': 9732,
#  'lung': 5136,
#  'heavily': 3950,
#  'mine': 5427,
#  'glassdoor': 3671,
#  'miserably': 5454,
#  'hat': 3899,
#  'magic': 5154,
#  'formula': 3416,
#  'unless': 9081,
#  'customer': 2078,
#  'service': 7636,
#  'unrealistic': 9107,
#  'decade': 2173,
#  'albeit': 250,
#  'magical': 5155,
#  'qualification': 6819,
#  'tree': 8856,
#  'hide': 3995,
#  'yes': 9717,
#  'ethical': 2963,
#  'different': 2372,
#  'transferable': 8829,
#  'procedure': 6663,
#  'differ': 2370,
#  'mean': 5284,
#  'onboarde': 5946,
#  'awake': 626,
#  'tired': 8725,
#  'worried': 9647,
#  'tv': 8931,
#  'volume': 9350,
#  'hype': 4193,
#  'club': 1526,
#  'music': 5622,
#  'fo': 3358,
#  'session': 7638,
#  'surf': 8385,
#  'reddit': 6998,
#  'obvious': 5884,
#  'benefit': 816,
#  'constantly': 1785,
#  'mirror': 5449,
#  'reminder': 7100,
#  'thx': 8684,
#  'conversation': 1835,
#  'exception': 3016,
#  'distance': 2490,
#  'main': 5164,
#  'perfect': 6272,
#  'hr': 4135,
#  'discussion': 2446,
#  'exclusion': 3029,
#  'per': 6266,
#  'rational': 6904,
#  'american': 324,
#  'recruiter': 6991,
#  'hiding': 3996,
#  'hb': 3909,
#  'holder': 4050,
#  'ill': 4238,
#  'kill': 4765,
#  'soon': 7982,
#  'clock': 1508,
#  'enough': 2875,
#  'wrong': 9672,
#  'what': 9509,
#  'ridiculously': 7294,
#  'name': 5647,
#  'guy': 3826,
#  'toxic': 8790,
#  'grind': 3784,
#  'jr': 4701,
#  'sysadmin': 8460,
#  'suck': 8326,
#  'book': 956,
#  'he': 3914,
#  'mod': 5486,
#  'appreciation': 435,
#  'grateful': 3756,
#  'grant': 3751,
#  'slacking': 7846,
#  'crazy': 1966,
#  'trust': 8892,
#  'pto': 6764,
#  'smart': 7884,
#  'okay': 5932,
#  'fellow': 3209,
#  'moron': 5553,
#  'listen': 5006,
#  'laundry': 4863,
#  'meet': 5316,
#  'lucky': 5126,
#  'noticed': 5817,
#  'pick': 6351,
#  'bark': 720,
#  'piece': 6360,
#  'cardboard': 1249,
#  'carpet': 1269,
#  'package': 6119,
#  'wtf': 9675,
#  'soft': 7948,
#  'smash': 7887,
#  'scream': 7523,
#  'grab': 3731,
#  'vacuum': 9220,
#  'priority': 6643,
#  'medium': 5313,
#  'idk': 4224,
#  'extent': 3095,
#  'track': 8797,
#  'ip': 4583,
#  'address': 126,
#  'security': 7571,
#  'purpose': 6794,
#  'vpn': 9364,
#  'reason': 6945,
#  'hear': 3936,
#  'taxis': 8512,
#  'plus': 6440,
#  'commute': 1644,
#  'democrats': 2252,
#  'claim': 1462,
#  'champion': 1338,
#  'pressure': 6608,
#  'publicly': 6770,
#  'endorse': 2851,
#  'least': 4895,
#  'former': 3414,
#  'argument': 465,
#  'sense': 7611,
#  'true': 8889,
#  'collaborate': 1574,
#  'locality': 5044,
#  'yet': 9720,
#  'international': 4524,
#  'national': 5660,
#  'pandemic': 6139,
#  'privilege': 6649,
#  'fire': 3272,
#  'they': 8641,
#  'entitlement': 2896,
#  'frankly': 3447,
#  'entitle': 2894,
#  'sign': 7763,
#  'fall': 3141,
#  'depression': 2288,
#  'reply': 7150,
#  'stage': 8124,
#  'point': 6457,
#  'decent': 2178,
#  'exhaust': 3042,
#  'dead': 2156,
#  'rest': 7219,
#  'custom': 2077,
#  'ready': 6929,
#  'feature': 3193,
#  'lock': 5048,
#  'podcast': 6456,
#  'dog': 2547,
#  'amazing': 308,
#  'fresh': 3468,
#  'air': 233,
#  'clean': 1479,
#  'brain': 1014,
#  'personal': 6300,
#  'peloton': 6251,
#  'tough': 8778,
#  'nap': 5649,
#  'yep': 9716,
#  'guilty': 3816,
#  'announcement': 365,
#  'unwell': 9133,
#  'loan': 5038,
#  'blast': 888,
#  'family': 3148,
#  'have': 3905,
#  'happen': 3875,
#  'there': 8636,
#  'gain': 3558,
#  'change': 1340,
#  'certain': 1324,
#  'ample': 331,
#  'worry': 9648,
#  'pain': 6125,
#  'preference': 6578,
#  'structure': 8273,
#  'group': 3795,
#  'friend': 3476,
#  'hangout': 3874,
#  'worth': 9654,
#  'beg': 788,
#  'lawsuit': 4867,
#  'referral': 7014,
#  'helpful': 3970,
#  'drink': 2637,
#  'generally': 3612,
#  'save': 7467,
#  'confident': 1735,
#  'quiet': 6840,
#  'off': 5903,
#  'troubleshoot': 8883,
#  'fix': 3296,
#  'environmemtalism': 2904,
#  'buy': 1161,
#  'electric': 2778,
#  'car': 1244,
#  'solve': 7966,
#  'rat': 6897,
#  'race': 6853,
#  'flexjobscom': 3328,
#  'curate': 2054,
#  'hell': 3961,
#  'pleasantry': 6421,
#  'wednesday': 9469,
#  'halfway': 3845,
#  'friday': 3474,
#  'crappy': 1958,
#  'co': 1539,
#  'delaware': 2226,
#  'hit': 4037,
#  'overtime': 6099,
#  'cope': 1866,
#  'executive': 3037,
#  'disagree': 2418,
#  'hybrid': 4187,
#  'york': 9730,
#  'times': 8712,
#  'leadership': 4882,
#  'fulfilling': 3513,
#  'fun': 3523,
#  'distinctly': 2495,
#  'recall': 6956,
#  'various': 9243,
#  'manager': 5189,
#  'suppose': 8379,
#  'beach': 755,
#  'girlfriend': 3657,
#  'beck': 772,
#  'ignore': 4232,
#  ...}

# %%
from sklearn.pipeline import Pipeline
from sklearn.feature_selection import SelectKBest, chi2  # Import SelectKBest and chi2
from sklearn.feature_extraction.text import TfidfTransformer, CountVectorizer
from sklearn.svm import LinearSVC

opt_pipeline = Pipeline([
    ('sel', SelectKBest(chi2)),  # feature selection
    ('tfidf', TfidfTransformer()),  # weighting
    ('learner', LinearSVC())  # learning algorithm
])

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import loguniform  

budget = 10

r_param_grid = [
    {'sel__k': [200, 1000, 2000, 3000, 4000, 'all'], 'learner__C': loguniform(0.01, 100)},  
]

optr_search = RandomizedSearchCV(opt_pipeline, r_param_grid, cv=5, n_iter=budget, n_jobs=3, verbose=True).fit(X_train_tok, y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits

# %%
optr_search.best_params_
# Out:
# {'learner__C': 11.356982605508229, 'sel__k': 4000}

# %%
X_test_tok
# Out:
# <24474x9760 sparse matrix of type '<class 'numpy.int64'>'
# 	with 463526 stored elements in Compressed Sparse Row format>

# %%
optr_predictions = optr_search.best_estimator_.predict(X_test_tok)

from sklearn.metrics import classification_report, accuracy_score

print(f"Accuracy: {accuracy_score(y_test, optr_predictions)}")

print("Classification Report:")
print(classification_report(y_test, optr_predictions))
# Out:
# Accuracy: 0.7365367328593609
# Classification Report:
#               precision    recall  f1-score   support
#
#        anger       0.71      0.71      0.71      7417
#         fear       0.66      0.51      0.57      3014
#          joy       0.77      0.85      0.81     10865
#         love       0.40      0.22      0.28       122
#      sadness       0.74      0.66      0.70      2804
#     surprise       0.67      0.63      0.65       252
#
#     accuracy                           0.74     24474
#    macro avg       0.66      0.60      0.62     24474
# weighted avg       0.73      0.74      0.73     24474

# %% [markdown]
# ## Non-linear SVM

# %%
from sklearn.svm import SVC

# create the pipeline with SVM and linear kernel
opt_pipeline_linear = Pipeline([
    ('sel', SelectKBest(chi2)),  # feature selection
    ('tfidf', TfidfTransformer()),  # weighting
    ('learner', SVC(kernel='linear'))  
])

# define the parameter grid for RandomizedSearchCV
r_param_grid_linear = [
    {'sel__k': [2000, 3000], 
     'learner__C': loguniform(0.01, 100),  # C parameter of the SVM
     'learner__gamma': ['scale', 'auto']}  
]

# %%
budget = 2  # Number of iterations
optr_search_linear= RandomizedSearchCV(opt_pipeline_linear, r_param_grid_linear, cv=2, n_iter=budget, n_jobs=-1, verbose=True)
optr_search_linear.fit(X_train_tok, y_train)

best_model_linear = optr_search_linear.best_estimator_
# Out:
# Fitting 2 folds for each of 2 candidates, totalling 4 fits

# %%
optr_search_linear.best_params_
# Out:
# {'learner__C': 4.4287938947563505, 'learner__gamma': 'scale', 'sel__k': 3000}

# %%
y_pred_linear = best_model_linear.predict(X_test_tok)
print(f"Accuracy: {accuracy_score(y_test, y_pred_linear)}")

print("Classification Report:")
print(classification_report(y_test, y_pred_linear))
# Out:
# Accuracy: 0.736414153795865
# Classification Report:
#               precision    recall  f1-score   support
#
#        anger       0.69      0.72      0.71      7417
#         fear       0.65      0.51      0.57      3014
#          joy       0.78      0.83      0.81     10865
#         love       0.58      0.24      0.34       122
#      sadness       0.75      0.68      0.71      2804
#     surprise       0.69      0.63      0.66       252
#
#     accuracy                           0.74     24474
#    macro avg       0.69      0.60      0.63     24474
# weighted avg       0.73      0.74      0.73     24474
