# %%
#Imports
from transformers import pipeline
import pandas as pd

#For deleting models from your machine
#pip install huggingface_hub["cli"]
#huggingface-cli delete-cache

# %%
#Load the pre-tuned model
distil_ROBERTa_model = 'michellejieli/emotion_text_classifier'

emotion_classifier = pipeline("sentiment-analysis", model=distil_ROBERTa_model)

# %%
# Load the csv file containing text from X and Reddit
social_media_data = pd.read_csv('../Data preprocessing/merged_df_91.csv')
#social_media_data = social_media_data.iloc[4000:4900]

# %%
# Classify the text column and store the results in a new column
social_media_data['predictions'] = social_media_data['text'].apply(lambda x: emotion_classifier(x)[0]['label'])

social_media_data.head(5)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 2
#       1 # Classify the text column and store the results in a new column
# ----> 2 social_media_data['predictions'] = social_media_data['text'].apply(lambda x: emotion_classifier(x)[0]['label'])
#       4 social_media_data.head(5)
#
# File /opt/miniconda3/envs/masterDS-exp/lib/python3.11/site-packages/pandas/core/series.py:4630, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4520 def apply(
#    4521     self,
#    4522     func: AggFuncType,
#    (...)
#    4525     **kwargs,
#    4526 ) -> DataFrame | Series:
#    4527     """
#    4528     Invoke function on values of Series.
#    4529
#    (...)
#    4628     dtype: float64
#    4629     """
# -> 4630     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File /opt/miniconda3/envs/masterDS-exp/lib/python3.11/site-packages/pandas/core/apply.py:1025, in SeriesApply.apply(self)
#    1022     return self.apply_str()
#    1024 # self.f is Callable
# -> 1025 return self.apply_standard()
#
# File /opt/miniconda3/envs/masterDS-exp/lib/python3.11/site-packages/pandas/core/apply.py:1076, in SeriesApply.apply_standard(self)
#    1074     else:
#    1075         values = obj.astype(object)._values
# -> 1076         mapped = lib.map_infer(
#    1077             values,
#    1078             f,
#    1079             convert=self.convert_dtype,
#    1080         )
#    1082 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1083     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1084     #  See also GH#25959 regarding EA support
#    1085     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File /opt/miniconda3/envs/masterDS-exp/lib/python3.11/site-packages/pandas/_libs/lib.pyx:2834, in pandas._libs.lib.map_infer()
#
# Cell In[22], line 2, in <lambda>(x)
#       1 # Classify the text column and store the results in a new column
# ----> 2 social_media_data['predictions'] = social_media_data['text'].apply(lambda x: emotion_classifier(x)[0]['label'])
#       4 social_media_data.head(5)
#
# File /opt/miniconda3/envs/masterDS-exp/lib/python3.11/site-packages/transformers/pipelines/text_classification.py:159, in TextClassificationPipeline.__call__(self, inputs, **kwargs)
#     124 """
#     125 Classify the text(s) given as inputs.
#     126
#    (...)
#     156     If `top_k` is used, one such dictionary is returned per label.
#     157 """
#     158 inputs = (inputs,)
# --> 159 result = super().__call__(*inputs, **kwargs)
#     160 # TODO try and retrieve it in a nicer way from _sanitize_parameters.
#     161 _legacy = "top_k" not in kwargs
#
# File /opt/miniconda3/envs/masterDS-exp/lib/python3.11/site-packages/transformers/pipelines/base.py:1302, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1294     return next(
#    1295         iter(
#    1296             self.get_iterator(
#    (...)
#    1299         )
#    1300     )
#    1301 else:
# -> 1302     return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#
# File /opt/miniconda3/envs/masterDS-exp/lib/python3.11/site-packages/transformers/pipelines/base.py:1309, in Pipeline.run_single(self, inputs, preprocess_params, forward_params, postprocess_params)
#    1307 def run_single(self, inputs, preprocess_params, forward_params, postprocess_params):
#    1308     model_inputs = self.preprocess(inputs, **preprocess_params)
# -> 1309     model_outputs = self.forward(model_inputs, **forward_params)
#    1310     outputs = self.postprocess(model_outputs, **postprocess_params)
#    1311     return outputs
#
# File /opt/miniconda3/envs/masterDS-exp/lib/python3.11/site-packages/transformers/pipelines/base.py:1209, in Pipeline.forward(self, model_inputs, **forward_params)
#    1207     with inference_context():
#    1208         model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1209         model_outputs = self._forward(model_inputs, **forward_params)
#    1210         model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1211 else:
#
# File /opt/miniconda3/envs/masterDS-exp/lib/python3.11/site-packages/transformers/pipelines/text_classification.py:190, in TextClassificationPipeline._forward(self, model_inputs)
#     188 if "use_cache" in inspect.signature(model_forward).parameters.keys():
#     189     model_inputs["use_cache"] = False
# --> 190 return self.model(**model_inputs)
#
# File /opt/miniconda3/envs/masterDS-exp/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File /opt/miniconda3/envs/masterDS-exp/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File /opt/miniconda3/envs/masterDS-exp/lib/python3.11/site-packages/transformers/models/roberta/modeling_roberta.py:1318, in RobertaForSequenceClassification.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict)
#    1310 r"""
#    1311 labels (`torch.LongTensor` of shape `(batch_size,)`, *optional*):
#    1312     Labels for computing the sequence classification/regression loss. Indices should be in `[0, ...,
#    1313     config.num_labels - 1]`. If `config.num_labels == 1` a regression loss is computed (Mean-Square loss), If
#    1314     `config.num_labels > 1` a classification loss is computed (Cross-Entropy).
#    1315 """
#    1316 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# -> 1318 outputs = self.roberta(
#    1319     input_ids,
#    1320     attention_mask=attention_mask,
#    1321     token_type_ids=token_type_ids,
#    1322     position_ids=position_ids,
#    1323     head_mask=head_mask,
#    1324     inputs_embeds=inputs_embeds,
#    1325     output_attentions=output_attentions,
#    1326     output_hidden_states=output_hidden_states,
#    1327     return_dict=return_dict,
#    1328 )
#    1329 sequence_output = outputs[0]
#    1330 logits = self.classifier(sequence_output)
#
# File /opt/miniconda3/envs/masterDS-exp/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File /opt/miniconda3/envs/masterDS-exp/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File /opt/miniconda3/envs/masterDS-exp/lib/python3.11/site-packages/transformers/models/roberta/modeling_roberta.py:976, in RobertaModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     969 # Prepare head mask if needed
#     970 # 1.0 in head_mask indicate we keep the head
#     971 # attention_probs has shape bsz x n_heads x N x N
#     972 # input head_mask has shape [num_heads] or [num_hidden_layers x num_heads]
#     973 # and head_mask is converted to shape [num_hidden_layers x batch x num_heads x seq_length x seq_length]
#     974 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
# --> 976 encoder_outputs = self.encoder(
#     977     embedding_output,
#     978     attention_mask=extended_attention_mask,
#     979     head_mask=head_mask,
#     980     encoder_hidden_states=encoder_hidden_states,
#     981     encoder_attention_mask=encoder_extended_attention_mask,
#     982     past_key_values=past_key_values,
#     983     use_cache=use_cache,
#     984     output_attentions=output_attentions,
#     985     output_hidden_states=output_hidden_states,
#     986     return_dict=return_dict,
#     987 )
#     988 sequence_output = encoder_outputs[0]
#     989 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File /opt/miniconda3/envs/masterDS-exp/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File /opt/miniconda3/envs/masterDS-exp/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File /opt/miniconda3/envs/masterDS-exp/lib/python3.11/site-packages/transformers/models/roberta/modeling_roberta.py:631, in RobertaEncoder.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     620     layer_outputs = self._gradient_checkpointing_func(
#     621         layer_module.__call__,
#     622         hidden_states,
#    (...)
#     628         output_attentions,
#     629     )
#     630 else:
# --> 631     layer_outputs = layer_module(
#     632         hidden_states,
#     633         attention_mask,
#     634         layer_head_mask,
#     635         encoder_hidden_states,
#     636         encoder_attention_mask,
#     637         past_key_value,
#     638         output_attentions,
#     639     )
#     641 hidden_states = layer_outputs[0]
#     642 if use_cache:
#
# File /opt/miniconda3/envs/masterDS-exp/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File /opt/miniconda3/envs/masterDS-exp/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File /opt/miniconda3/envs/masterDS-exp/lib/python3.11/site-packages/transformers/models/roberta/modeling_roberta.py:562, in RobertaLayer.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     559     cross_attn_present_key_value = cross_attention_outputs[-1]
#     560     present_key_value = present_key_value + cross_attn_present_key_value
# --> 562 layer_output = apply_chunking_to_forward(
#     563     self.feed_forward_chunk, self.chunk_size_feed_forward, self.seq_len_dim, attention_output
#     564 )
#     565 outputs = (layer_output,) + outputs
#     567 # if decoder, return the attn key/values as the last output
#
# File /opt/miniconda3/envs/masterDS-exp/lib/python3.11/site-packages/transformers/pytorch_utils.py:248, in apply_chunking_to_forward(forward_fn, chunk_size, chunk_dim, *input_tensors)
#     245     # concatenate output at same dimension
#     246     return torch.cat(output_chunks, dim=chunk_dim)
# --> 248 return forward_fn(*input_tensors)
#
# File /opt/miniconda3/envs/masterDS-exp/lib/python3.11/site-packages/transformers/models/roberta/modeling_roberta.py:574, in RobertaLayer.feed_forward_chunk(self, attention_output)
#     573 def feed_forward_chunk(self, attention_output):
# --> 574     intermediate_output = self.intermediate(attention_output)
#     575     layer_output = self.output(intermediate_output, attention_output)
#     576     return layer_output
#
# File /opt/miniconda3/envs/masterDS-exp/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File /opt/miniconda3/envs/masterDS-exp/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File /opt/miniconda3/envs/masterDS-exp/lib/python3.11/site-packages/transformers/models/roberta/modeling_roberta.py:473, in RobertaIntermediate.forward(self, hidden_states)
#     471 def forward(self, hidden_states: torch.Tensor) -> torch.Tensor:
#     472     hidden_states = self.dense(hidden_states)
# --> 473     hidden_states = self.intermediate_act_fn(hidden_states)
#     474     return hidden_states
#
# File /opt/miniconda3/envs/masterDS-exp/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File /opt/miniconda3/envs/masterDS-exp/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File /opt/miniconda3/envs/masterDS-exp/lib/python3.11/site-packages/transformers/activations.py:78, in GELUActivation.forward(self, input)
#      77 def forward(self, input: Tensor) -> Tensor:
# ---> 78     return self.act(input)
#
# KeyboardInterrupt:

# %%
# Save the dataframe with the predictions to a new CSV
social_media_data.to_csv("labeled_data.csv", index=False)
