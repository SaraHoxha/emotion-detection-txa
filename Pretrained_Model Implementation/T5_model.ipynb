# %%
# !pip install emoji

# %%
import emoji
import nltk
import pandas as pd
import re
import requests

from transformers import AutoTokenizer, AutoModelWithLMHead

# %% [markdown]
# # Data Uploading

# %%
url = "https://raw.githubusercontent.com/SaraHoxha/emotion-detection-txa/refs/heads/main/Data%20Preprocessing/merged_df_flitered_version.csv"
df = pd.read_csv(url)

# %%
df['filtered_text'] = df['filtered_text'].fillna('').astype(str) # Replace nulls with blanks

# %% [markdown]
# # Data Cleaning
#
# This step is specific to this model, texts larger than the maximum character limit allowed by T5, which is 510, will be removed.

# %%
def count_characters(text):
    return len(text)

df['character_count'] = df['filtered_text'].apply(count_characters)

# %%
df = df[df['character_count'] <= 510] # Drop bigger rows

df
# Out:
#             id                                               text  \
# 0            1  easy ways to stop video conference screen free...
# 1            2  in the age of remoteworking you can work from ...
# 2            3  after the pandemic of covid remote working is ...
# 3            4  do employee monitoring tools have any place in...
# 4            5  a little paint lots of productivity and a whol...
# ...        ...                                                ...
# 177810  177811      call center jobs are mostly remote these days
# 177811  177812     i think data entry jobs also fit this criteria
# 177812  177813  it work not all of them require a degree i nev...
# 177813  177814    never done data entry what all does it involve?
# 177814  177815               mostly knowledge of microsoft office
#
#                 created_utc  likes   source  \
# 0       2024-10-14 14:59:40      0  Twitter
# 1       2024-10-14 14:05:20      0  Twitter
# 2       2024-10-14 12:30:23      0  Twitter
# 3       2024-10-14 12:22:40      0  Twitter
# 4       2024-10-14 12:22:03      0  Twitter
# ...                     ...    ...      ...
# 177810  2022-06-12 04:02:05      3   Reddit
# 177811  2022-06-12 18:01:16      1   Reddit
# 177812  2022-06-22 18:22:45      1   Reddit
# 177813  2022-06-14 15:24:38      2   Reddit
# 177814  2022-06-15 16:14:15      1   Reddit
#
#                                             filtered_text  \
# 0       easy way stop video conference screen freeze o...
# 1                         age remoteworke work need start
# 2       pandemic covid remote working increase globe b...
# 3       employee monitoring tool have place remote wor...
# 4       little paint lot productivity whole new vibe c...
# ...                                                   ...
# 177810                         call center job remote day
# 177811                 think data entry job fit criterion
# 177812    work require degree get have 20 year experience
# 177813                     do data entry involve question
# 177814                                   knowledge office
#
#                                                    tokens  character_count
# 0       ['easy', 'way', 'stop', 'video', 'conference',...              235
# 1         ['age', 'remoteworke', 'work', 'need', 'start']               92
# 2       ['pandemic', 'covid', 'remote', 'working', 'in...              258
# 3       ['employee', 'monitoring', 'tool', 'have', 'pl...              209
# 4       ['little', 'paint', 'lot', 'productivity', 'wh...              229
# ...                                                   ...              ...
# 177810         ['call', 'center', 'job', 'remote', 'day']               45
# 177811  ['think', 'data', 'entry', 'job', 'fit', 'crit...               46
# 177812  ['work', 'require', 'degree', 'get', 'have', '...               88
# 177813     ['do', 'data', 'entry', 'involve', 'question']               47
# 177814                            ['knowledge', 'office']               36
#
# [161047 rows x 8 columns]

# %% [markdown]
# # Model Implementation
#
# For this step, Google's T5 Base fine-tuned model obtained from HuggingFace (https://huggingface.co/mrm8488/t5-base-finetuned-emotion) will be implemented to create the ground truth of the emotion labels. In this case, the emotions belonging to the possible labels match Parrot's emotions.

# %%
tokenizer = AutoTokenizer.from_pretrained("mrm8488/t5-base-finetuned-emotion")
model = AutoModelWithLMHead.from_pretrained("mrm8488/t5-base-finetuned-emotion")

def get_emotion(text): # Emotions predictor
    input_ids = tokenizer.encode(text + '</s>', return_tensors='pt')
    output = model.generate(input_ids=input_ids, max_length=2)
    dec = [tokenizer.decode(ids) for ids in output]
    label = dec[0]
    return label

df['predicted_label'] = df['filtered_text'].apply(get_emotion)
# Out:
# c:\Users\Usuario\anaconda3\Lib\site-packages\transformers\models\auto\modeling_auto.py:1833: FutureWarning: The class `AutoModelWithLMHead` is deprecated and will be removed in a future version. Please use `AutoModelForCausalLM` for causal language models, `AutoModelForMaskedLM` for masked language models and `AutoModelForSeq2SeqLM` for encoder-decoder models.
#   warnings.warn(

# %%
df.head()
# Out:
#    id                                               text          created_utc  \
# 0   1  easy ways to stop video conference screen free...  2024-10-14 14:59:40
# 1   2  in the age of remoteworking you can work from ...  2024-10-14 14:05:20
# 2   3  after the pandemic of covid remote working is ...  2024-10-14 12:30:23
# 3   4  do employee monitoring tools have any place in...  2024-10-14 12:22:40
# 4   5  a little paint lots of productivity and a whol...  2024-10-14 12:22:03
#
#    likes   source                                      filtered_text  \
# 0      0  Twitter  easy way stop video conference screen freeze o...
# 1      0  Twitter                    age remoteworke work need start
# 2      0  Twitter  pandemic covid remote working increase globe b...
# 3      0  Twitter  employee monitoring tool have place remote wor...
# 4      0  Twitter  little paint lot productivity whole new vibe c...
#
#                                               tokens  character_count  \
# 0  ['easy', 'way', 'stop', 'video', 'conference',...              205
# 1    ['age', 'remoteworke', 'work', 'need', 'start']               31
# 2  ['pandemic', 'covid', 'remote', 'working', 'in...              182
# 3  ['employee', 'monitoring', 'tool', 'have', 'pl...              149
# 4  ['little', 'paint', 'lot', 'productivity', 'wh...              170
#
#   predicted_label
# 0       <pad> joy
# 1      <pad> fear
# 2      <pad> fear
# 3     <pad> anger
# 4       <pad> joy

# %%
df.value_counts('predicted_label')
# Out:
# predicted_label
# <pad> joy            75261
# <pad> anger          53628
# <pad> fear           28331
# <pad> sadness        13133
# <pad> surprise        1826
# <pad> love             810
# <pad> interest         203
# <pad> 100               53
# <pad> remote            16
# <pad> cat               12
# <pad> not               10
# <pad> commercial         8
# <pad> tech               5
# <pad> double             5
# <pad> dream              4
# <pad> vitamin            4
# <pad> hybrid             3
# <pad> treadmill          3
# <pad> legal              3
# <pad> bait               2
# <pad> clutch             2
# <pad> hunger             1
# <pad> bus                1
# <pad> 99                 1
# <pad> union              1
# <pad> tornado            1
# <pad> blanket            1
# <pad> blue               1
# <pad> sub                1
# <pad> standard           1
# <pad> ski                1
# <pad> silent             1
# <pad> silence            1
# <pad> rock               1
# <pad> grape              1
# <pad> candle             1
# <pad> piano              1
# <pad> persistence        1
# <pad> clean              1
# <pad> milk               1
# <pad> mayor              1
# <pad> logistic           1
# <pad> liquid             1
# <pad> 110                1
# <pad> draft              1
# <pad> dry                1
# <pad> white              1
# Name: count, dtype: int64

# %%
df[df['predicted_label'] == '<pad> interest']
# Out:
#             id                                               text  \
# 20792    20793                                         interested
# 23121    23122     would you be interested in spaghetti tutoring?
# 44298    44299                                         interested
# 46981    46982                id be incredibly interested in that
# 47203    47204                                         interested
# ...        ...                                                ...
# 176250  176251  for anyone who is interested in the zbd positions
# 176489  176490                                hey i am interested
# 176703  176704                                    i am interested
# 176883  176884                                    i am interested
# 176885  176886                                    i am interested
#
#                 created_utc  likes  source  \
# 20792   2024-02-10 04:00:21      1  Reddit
# 23121   2023-10-14 02:32:54      1  Reddit
# 44298   2024-07-15 17:30:10      0  Reddit
# 46981   2023-04-10 13:40:55      3  Reddit
# 47203   2024-06-12 11:17:29      2  Reddit
# ...                     ...    ...     ...
# 176250  2024-09-09 20:14:02      2  Reddit
# 176489  2024-04-23 21:32:56      1  Reddit
# 176703  2023-10-08 09:02:48      1  Reddit
# 176883  2023-01-12 05:55:34      1  Reddit
# 176885  2023-01-12 09:42:55      1  Reddit
#
#                                  filtered_text  \
# 20792                               interested
# 23121   interested spaghetti tutoring question
# 44298                               interested
# 46981                             d interested
# 47203                               interested
# ...                                        ...
# 176250                 interested zbd position
# 176489                              interested
# 176703                              interested
# 176883                              interested
# 176885                              interested
#
#                                                    tokens  character_count  \
# 20792                                      ['interested']               10
# 23121   ['interested', 'spaghetti', 'tutoring', 'quest...               38
# 44298                                      ['interested']               10
# 46981                                 ['d', 'interested']               12
# 47203                                      ['interested']               10
# ...                                                   ...              ...
# 176250                  ['interested', 'zbd', 'position']               23
# 176489                                     ['interested']               10
# 176703                                     ['interested']               10
# 176883                                     ['interested']               10
# 176885                                     ['interested']               10
#
#        predicted_label
# 20792   <pad> interest
# 23121   <pad> interest
# 44298   <pad> interest
# 46981   <pad> interest
# 47203   <pad> interest
# ...                ...
# 176250  <pad> interest
# 176489  <pad> interest
# 176703  <pad> interest
# 176883  <pad> interest
# 176885  <pad> interest
#
# [203 rows x 9 columns]

# %%
df_filtered = df 
df_filtered['predicted_label'] = df_filtered['predicted_label'].str.replace(r'^<pad>\s*', '', regex=True)

# %% [markdown]
# As observed above, there are labels that do not correspond to real emotions, since the model assigns the most frequent non-stopword as the label when there is not enough information no assign a emotion. These observations usually do not provide emotional context, so they will be removed.

# %%
keywords = ['fear', 'joy', 'sadness', 'surprise', 'anger', 'love', 'interest' ] 
pattern = '|'.join(keywords)  # Create a pattern to search for any keyword

df_filtered = df_filtered[df_filtered['predicted_label'].str.contains(pattern, case=False, regex=True)]  # Retain only rows labeled as Parrot's emotions
df_filtered
# Out:
#             id                                               text  \
# 0            1  easy ways to stop video conference screen free...
# 1            2  in the age of remoteworking you can work from ...
# 2            3  after the pandemic of covid remote working is ...
# 3            4  do employee monitoring tools have any place in...
# 4            5  a little paint lots of productivity and a whol...
# ...        ...                                                ...
# 177810  177811      call center jobs are mostly remote these days
# 177811  177812     i think data entry jobs also fit this criteria
# 177812  177813  it work not all of them require a degree i nev...
# 177813  177814    never done data entry what all does it involve?
# 177814  177815               mostly knowledge of microsoft office
#
#                 created_utc  likes   source  \
# 0       2024-10-14 14:59:40      0  Twitter
# 1       2024-10-14 14:05:20      0  Twitter
# 2       2024-10-14 12:30:23      0  Twitter
# 3       2024-10-14 12:22:40      0  Twitter
# 4       2024-10-14 12:22:03      0  Twitter
# ...                     ...    ...      ...
# 177810  2022-06-12 04:02:05      3   Reddit
# 177811  2022-06-12 18:01:16      1   Reddit
# 177812  2022-06-22 18:22:45      1   Reddit
# 177813  2022-06-14 15:24:38      2   Reddit
# 177814  2022-06-15 16:14:15      1   Reddit
#
#                                             filtered_text  \
# 0       easy way stop video conference screen freeze o...
# 1                         age remoteworke work need start
# 2       pandemic covid remote working increase globe b...
# 3       employee monitoring tool have place remote wor...
# 4       little paint lot productivity whole new vibe c...
# ...                                                   ...
# 177810                         call center job remote day
# 177811                 think data entry job fit criterion
# 177812    work require degree get have 20 year experience
# 177813                     do data entry involve question
# 177814                                   knowledge office
#
#                                                    tokens  character_count  \
# 0       ['easy', 'way', 'stop', 'video', 'conference',...              235
# 1         ['age', 'remoteworke', 'work', 'need', 'start']               92
# 2       ['pandemic', 'covid', 'remote', 'working', 'in...              258
# 3       ['employee', 'monitoring', 'tool', 'have', 'pl...              209
# 4       ['little', 'paint', 'lot', 'productivity', 'wh...              229
# ...                                                   ...              ...
# 177810         ['call', 'center', 'job', 'remote', 'day']               45
# 177811  ['think', 'data', 'entry', 'job', 'fit', 'crit...               46
# 177812  ['work', 'require', 'degree', 'get', 'have', '...               88
# 177813     ['do', 'data', 'entry', 'involve', 'question']               47
# 177814                            ['knowledge', 'office']               36
#
#        predicted_label
# 0                anger
# 1                  joy
# 2                 fear
# 3                anger
# 4                  joy
# ...                ...
# 177810            fear
# 177811             joy
# 177812             joy
# 177813            fear
# 177814            fear
#
# [160962 rows x 9 columns]

# %%
csv_path = ''
df_filtered.to_csv(csv_path, index=False)
